# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset (assuming it is in the same location as the notebook)
dataset_original = pd.read_csv("1429_1.csv")
dataset_add_01 = pd.read_csv("Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products.csv")
dataset_add_02 = pd.read_csv("Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products_May19.csv")
# Out:
# C:\Users\larry\AppData\Local\Temp\ipykernel_22220\3192637300.py:7: DtypeWarning: Columns (1,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset_original = pd.read_csv("1429_1.csv")

# %%
# Display the shape of the dataset
print(f"Original Dataset shape: {dataset_original.shape}")
print(f"\nAdditional Dataset 01 shape: {dataset_add_01.shape}")
print(f"\nAdditional Dataset 02 shape: {dataset_add_02.shape}")
# Out:
# Original Dataset shape: (34660, 21)
#
# Additional Dataset 01 shape: (5000, 24)
#
# Additional Dataset 02 shape: (28332, 24)

# %%
# Display the first few rows of the dataset
print("First rows of the Original Dataset:")
print(dataset_original.head())

print("\nFirst rows of the Additional Dataset 01:")
print(dataset_add_01.head())

print("\nFirst rows of the Additional Dataset 02:")
print(dataset_add_02.head())
# Out:
# First rows of the Original Dataset:
#                      id                                               name  \
# 0  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 1  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 3  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 4  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
#
#         asins   brand                                         categories  \
# 0  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 2  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 3  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 4  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
#
# ...

# %%
# Get general information about the dataset
print("\nOriginal Dataset information:")
print(dataset_original.info())

print("\nAdditional Dataset 01 information:")
print(dataset_add_01.info())

print("\nAdditional Dataset 02 information:")
print(dataset_add_02.info())
# Out:
# Original Dataset information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34660 entries, 0 to 34659
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    34660 non-null  object
#  1   name                  27900 non-null  object
#  2   asins                 34658 non-null  object
#  3   brand                 34660 non-null  object
#  4   categories            34660 non-null  object
#  5   keys                  34660 non-null  object
#  6   manufacturer          34660 non-null  object
#  7   reviews.date          34621 non-null  object
#  8   reviews.dateAdded     24039 non-null  object
#  9   reviews.dateSeen      34660 non-null  object
#  10  reviews.didPurchase   1 non-null      object
#  11  reviews.doRecommend   34066 non-null  object
#  12  reviews.id            1 non-null      float64
#  13  reviews.numHelpful    34131 non-null  float64
# ...

# %%
# Display descriptive statistics for the dataset
print("\nOriginal Dataset Descriptive statistics:")
print(dataset_original.describe(include='all'))

print("\nAdditional Dataset 01 Descriptive statistics:")
print(dataset_add_01.describe(include='all'))

print("\nAdditional Dataset 02 Descriptive statistics:")
print(dataset_add_02.describe(include='all'))
# Out:
# Original Dataset Descriptive statistics:
#                           id  \
# count                  34660
# unique                    42
# top     AVphgVaX1cnluZ0-DR74
# freq                   10966
# mean                     NaN
# std                      NaN
# min                      NaN
# 25%                      NaN
# 50%                      NaN
# 75%                      NaN
# max                      NaN
#
#                                                      name       asins   brand  \
# count                                               27900       34658   34660
# unique                                                 48          41       6
# top     Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes...  B018Y229OU  Amazon
# freq                                                10966       10966   28701
# mean                                                  NaN         NaN     NaN
# std                                                   NaN         NaN     NaN
# ...

# %%
# Display the column names in the dataset
print("\nOriginal Dataset Column names:")
print(dataset_original.columns)

print("\nAdditional Dataset 01 Column names:")
print(dataset_add_01.columns)

print("\nAdditional Dataset 02 Column names:")
print(dataset_add_02.columns)
# Out:
# Original Dataset Column names:
# Index(['id', 'name', 'asins', 'brand', 'categories', 'keys', 'manufacturer',
#        'reviews.date', 'reviews.dateAdded', 'reviews.dateSeen',
#        'reviews.didPurchase', 'reviews.doRecommend', 'reviews.id',
#        'reviews.numHelpful', 'reviews.rating', 'reviews.sourceURLs',
#        'reviews.text', 'reviews.title', 'reviews.userCity',
#        'reviews.userProvince', 'reviews.username'],
#       dtype='object')
#
# Additional Dataset 01 Column names:
# Index(['id', 'dateAdded', 'dateUpdated', 'name', 'asins', 'brand',
#        'categories', 'primaryCategories', 'imageURLs', 'keys', 'manufacturer',
#        'manufacturerNumber', 'reviews.date', 'reviews.dateAdded',
#        'reviews.dateSeen', 'reviews.doRecommend', 'reviews.id',
#        'reviews.numHelpful', 'reviews.rating', 'reviews.sourceURLs',
#        'reviews.text', 'reviews.title', 'reviews.username', 'sourceURLs'],
#       dtype='object')
#
# Additional Dataset 02 Column names:
# ...

# %%
# Check for missing values in the dataset
print("\nDataset Original Missing values by column:")
print(dataset_original.isnull().sum())

print("\nAdditional Dataset 01 Missing values by column:")
print(dataset_add_01.isnull().sum())

print("\nAdditional Dataset 02 Missing values by column:")
print(dataset_add_02.isnull().sum())
# Out:
# Dataset Original Missing values by column:
# id                          0
# name                     6760
# asins                       2
# brand                       0
# categories                  0
# keys                        0
# manufacturer                0
# reviews.date               39
# reviews.dateAdded       10621
# reviews.dateSeen            0
# reviews.didPurchase     34659
# reviews.doRecommend       594
# reviews.id              34659
# reviews.numHelpful        529
# reviews.rating             33
# reviews.sourceURLs          0
# reviews.text                1
# reviews.title               6
# reviews.userCity        34660
# reviews.userProvince    34660
# reviews.username            7
# dtype: int64
#
# Additional Dataset 01 Missing values by column:
# id                        0
# dateAdded                 0
# dateUpdated               0
# name                      0
# asins                     0
# brand                     0
# categories                0
# ...

# %%
# Check for duplicate rows in the dataset
print("\nOriginal Dataset Number of duplicate rows:")
print(dataset_original.duplicated().sum())

print("\nAdditional Dataset 01 Number of duplicate rows:")
print(dataset_add_01.duplicated().sum())

print("\nAdditional Dataset 02 Number of duplicate rows:")
print(dataset_add_02.duplicated().sum())
# Out:
# Original Dataset Number of duplicate rows:
# 0
#
# Additional Dataset 01 Number of duplicate rows:
# 95
#
# Additional Dataset 02 Number of duplicate rows:
# 0

# %%
# Remove duplicate rows if necessary
dataset_add_01 = dataset_add_01.drop_duplicates()
print("\nDataset shape after removing duplicates:")
print(dataset_add_01.shape)
# Out:
# Dataset shape after removing duplicates:
# (4905, 24)

# %%
print("\nAdditional Dataset 01 Number of duplicate rows:")
print(dataset_add_01.duplicated().sum())
# Out:
# Additional Dataset 01 Number of duplicate rows:
# 0

# %%
# Selection of Required Columns
columns_required = ['reviews.text', 'reviews.rating', 'reviews.doRecommend']
dataset_original = dataset_original[columns_required]
dataset_add_01 = dataset_add_01[columns_required]
dataset_add_02 = dataset_add_02[columns_required]

# %%
# Display the shape of the dataset
print(f"Original Dataset shape: {dataset_original.shape}")
print(f"\nAdditional Dataset 01 shape: {dataset_add_01.shape}")
print(f"\nAdditional Dataset 02 shape: {dataset_add_02.shape}")
# Out:
# Original Dataset shape: (34660, 3)
#
# Additional Dataset 01 shape: (4905, 3)
#
# Additional Dataset 02 shape: (28332, 3)

# %%
# Filter datasets by ratings 1, 2, y 3
dataset_add_01_filt = dataset_add_01[dataset_add_01['reviews.rating'].isin([1, 2, 3])]
dataset_add_02_filt = dataset_add_02[dataset_add_02['reviews.rating'].isin([1, 2, 3])]

# %%
# Combine datasets
combined_dataset = pd.concat([dataset_original, dataset_add_01_filt, dataset_add_02_filt], ignore_index=True)

# %%
# Display the shape of the dataset
print(f"Combined Dataset shape: {combined_dataset.shape}")
# Out:
# Combined Dataset shape: (37752, 3)

# %%
# Get general information about the dataset
print("\nCombined Dataset information:")
print(combined_dataset.info())
# Out:
# Combined Dataset information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37752 entries, 0 to 37751
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   reviews.text         37751 non-null  object
#  1   reviews.rating       37719 non-null  float64
#  2   reviews.doRecommend  35448 non-null  object
# dtypes: float64(1), object(2)
# memory usage: 884.9+ KB
# None

# %%
print("\nFirst rows of the Combined Dataset:")
print(combined_dataset.head())
# Out:
# First rows of the Combined Dataset:
#                                         reviews.text  reviews.rating  \
# 0  This product so far has not disappointed. My c...             5.0
# 1  great for beginner or experienced person. Boug...             5.0
# 2  Inexpensive tablet for him to use and learn on...             5.0
# 3  I've had my Fire HD 8 two weeks now and I love...             4.0
# 4  I bought this for my grand daughter when she c...             5.0
#
#   reviews.doRecommend
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True

# %%
# Analyze the distribution of the 'rating' column if it exists
if 'reviews.rating' in combined_dataset.columns:
    print("\nDistribution of ratings:")
    print(combined_dataset['reviews.rating'].value_counts())
    
    # Plot the distribution of ratings
    plt.figure(figsize=(8, 5))
    sns.countplot(x='reviews.rating', data=combined_dataset, palette='viridis')
    plt.title("Distribution of Ratings")
    plt.xlabel("Rating")
    plt.ylabel("Frequency")
    plt.show()
# Out:
# Distribution of ratings:
# reviews.rating
# 5.0    23775
# 4.0     8541
# 3.0     2898
# 1.0     1434
# 2.0     1071
# Name: count, dtype: int64
# C:\Users\larry\AppData\Local\Temp\ipykernel_22220\174753911.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='reviews.rating', data=combined_dataset, palette='viridis')

# %%
# Check the number of missing values in 'reviews.rating' before cleaning
print(f"Number of missing values in 'reviews.rating' before cleaning: {combined_dataset['reviews.rating'].isnull().sum()}")

# Drop rows where 'reviews.rating' is null
combined_dataset = combined_dataset.dropna(subset=['reviews.rating'])

# Confirm the missing values have been removed
print(f"Number of missing values in 'reviews.rating' after cleaning: {combined_dataset['reviews.rating'].isnull().sum()}")

# Check the shape of the dataset after cleaning
print(f"Dataset shape after removing missing values in 'reviews.rating': {combined_dataset.shape}")
# Out:
# Number of missing values in 'reviews.rating' before cleaning: 33
# Number of missing values in 'reviews.rating' after cleaning: 0
# Dataset shape after removing missing values in 'reviews.rating': (37719, 3)

# %%
# Check the number of missing values in 'reviews.text' before cleaning
print(f"Number of missing values in 'reviews.text' before cleaning: {combined_dataset['reviews.text'].isnull().sum()}")

# Drop rows where 'reviews.text' is null
combined_dataset = combined_dataset.dropna(subset=['reviews.text'])

# Confirm the missing values have been removed
print(f"Number of missing values in 'reviews.text' after cleaning: {combined_dataset['reviews.text'].isnull().sum()}")

# Check the shape of the dataset after cleaning
print(f"Dataset shape after removing missing values in 'reviews.text': {combined_dataset.shape}")
# Out:
# Number of missing values in 'reviews.text' before cleaning: 1
# Number of missing values in 'reviews.text' after cleaning: 0
# Dataset shape after removing missing values in 'reviews.text': (37718, 3)

# %% [markdown]
# # **Text Cleaning**

# %%
from nltk.corpus import stopwords
import nltk

nltk.download('stopwords')# Download stopwords if not already downloaded
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\larry\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re

# Define a function for cleaning text
def clean_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove punctuation and special characters
    text = re.sub(r'[^\w\s]', '', text)
    # Remove numbers
    text = re.sub(r'\d+', '', text)
    # Remove stopwords
    text = " ".join([word for word in text.split() if word not in stop_words])
    return text

comb_data_cleaned = combined_dataset.copy()  # Make a copy of the original dataset

# Apply text cleaning to the reviews.text column
print("Performing basic text cleaning...")
comb_data_cleaned['reviews.text'] = comb_data_cleaned['reviews.text'].apply(clean_text)

# Verify cleaned text
print("\nSample cleaned text:")
print(comb_data_cleaned['reviews.text'].head())
# Out:
# Performing basic text cleaning...
#
# Sample cleaned text:
# 0    product far disappointed children love use lik...
# 1    great beginner experienced person bought gift ...
# 2    inexpensive tablet use learn step nabi thrille...
# 3    ive fire hd two weeks love tablet great valuew...
# 4    bought grand daughter comes visit set user ent...
# Name: reviews.text, dtype: object

# %%
# Save the cleaned dataset for reference
output_file = "combined_data_cleaned.csv"
comb_data_cleaned.to_csv(output_file, index=False)
print(f"\nCleaned dataset saved as '{output_file}'")
# Out:
# Cleaned dataset saved as 'combined_data_cleaned.csv'

# %% [markdown]
# # **Adding Sentiment Feature**

# %%
# Create a new DataFrame with the selected features
comb_data_feat = comb_data_cleaned.copy()

# Add the 'sentiment' feature based on the mapping logic
def map_sentiment(rating):
    if rating in [1, 2]:
        return "negative"
    elif rating == 3:
        return "neutral"
    elif rating in [4, 5]:
        return "positive"

comb_data_feat['sentiment'] = comb_data_feat['reviews.rating'].apply(map_sentiment)

# %%
# Verify the new dataset
print("First rows of the new dataset:")
print(comb_data_feat.head())
# Out:
# First rows of the new dataset:
#                                         reviews.text  reviews.rating  \
# 0  product far disappointed children love use lik...             5.0
# 1  great beginner experienced person bought gift ...             5.0
# 2  inexpensive tablet use learn step nabi thrille...             5.0
# 3  ive fire hd two weeks love tablet great valuew...             4.0
# 4  bought grand daughter comes visit set user ent...             5.0
#
#   reviews.doRecommend sentiment
# 0                True  positive
# 1                True  positive
# 2                True  positive
# 3                True  positive
# 4                True  positive

# %%
# Check the shape of the new dataset
print(f"\nNew dataset shape: {comb_data_feat.shape}")
# Out:
# New dataset shape: (37718, 4)

# %%
# Distribution of the 'sentiment' feature
print("\nDistribution of 'sentiment':")
print(comb_data_feat['sentiment'].value_counts())
# Out:
# Distribution of 'sentiment':
# sentiment
# positive    32315
# neutral      2898
# negative     2505
# Name: count, dtype: int64

# %%
# Visualize the sentiment distribution
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.countplot(x='sentiment', data=comb_data_feat, palette='pastel', order=["negative", "neutral", "positive"])
plt.title("Distribution of Sentiment in the New Dataset")
plt.xlabel("Sentiment")
plt.ylabel("Frequency")
plt.show()
# Out:
# C:\Users\larry\AppData\Local\Temp\ipykernel_22220\2707556724.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sentiment', data=comb_data_feat, palette='pastel', order=["negative", "neutral", "positive"])

# %% [markdown]
# # **Two data sets Creation for 2 parallel approaches**

# %%
# Create two versions of the dataset
# Version 1: Drop 'doRecommend'
comb_dataset_drop = comb_data_feat[['reviews.text', 'reviews.rating', 'sentiment']]

# Version 2: Include 'doRecommend', recoding for neutral sentiment
comb_dataset_recode = comb_data_feat[['reviews.text', 'reviews.rating', 'sentiment', 'reviews.doRecommend']]
if 'reviews.doRecommend' in comb_dataset_recode.columns:
    comb_dataset_recode.loc[comb_dataset_recode['reviews.rating'] == 3, 'reviews.doRecommend'] = None

# %%
# Validation: Check for missing values in the datasets
print("\nChecking for missing values in the dataset_drop:")
print(comb_dataset_drop.isnull().sum())
print("\nChecking for missing values in the dataset_recode:")
print(comb_dataset_recode.isnull().sum())

# Validation: Verify unique values in the 'sentiment' column
print("\nUnique values in the 'sentiment' column in dataset_drop:")
print(comb_dataset_drop['sentiment'].unique())
print("\nUnique values in the 'sentiment' column in dataset_recode:")
print(comb_dataset_recode['sentiment'].unique())
# Out:
# Checking for missing values in the dataset_drop:
# reviews.text      0
# reviews.rating    0
# sentiment         0
# dtype: int64
#
# Checking for missing values in the dataset_recode:
# reviews.text              0
# reviews.rating            0
# sentiment                 0
# reviews.doRecommend    4592
# dtype: int64
#
# Unique values in the 'sentiment' column in dataset_drop:
# ['positive' 'negative' 'neutral']
#
# Unique values in the 'sentiment' column in dataset_recode:
# ['positive' 'negative' 'neutral']

# %%
# Count missing values in 'reviews.doRecommend' grouped by sentiment
print("Missing values in 'reviews.doRecommend' grouped by sentiment:")
missing_counts = comb_dataset_recode.groupby('sentiment')['reviews.doRecommend'].apply(lambda x: x.isnull().sum())
print(missing_counts)
# Out:
# Missing values in 'reviews.doRecommend' grouped by sentiment:
# sentiment
# negative    1237
# neutral     2898
# positive     457
# Name: reviews.doRecommend, dtype: int64

# %%
# Remove rows with missing 'doRecommend' in positive and negative sentiments
comb_dataset_recode = comb_dataset_recode[
    ~((comb_dataset_recode['sentiment'].isin(['positive', 'negative'])) & (comb_dataset_recode['reviews.doRecommend'].isnull()))
]

# Confirm removal of rows
print("Missing values after cleaning:")
cleaned_counts = comb_dataset_recode.groupby('sentiment')['reviews.doRecommend'].apply(lambda x: x.isnull().sum())
print(cleaned_counts)
# Out:
# Missing values after cleaning:
# sentiment
# negative       0
# neutral     2898
# positive       0
# Name: reviews.doRecommend, dtype: int64

# %%
# Verify datasets shape
print(f"\nShape for dataset_drop: {comb_dataset_drop.shape}")
print(f"Shape for dataset_recode: {comb_dataset_recode.shape}")
# Out:
# Shape for dataset_drop: (37718, 3)
# Shape for dataset_recode: (36024, 4)

# %%
# Display a random sample of rows to verify the mapping
print("\nSample rows from the dataset_drop for validation:")
print(comb_dataset_drop.sample(5))
print("\nSample rows from the dataset_recode for validation:")
print(comb_dataset_recode.sample(5))
# Out:
# Sample rows from the dataset_drop for validation:
#                                             reviews.text  reviews.rating  \
# 14906  bought mom rehab following shoulder surgery lo...             4.0
# 32141  fire stick makes great gifts family friends es...             4.0
# 1445             purchased due reviews sale far easy use             5.0
# 31787                  simple cable much cheaper compact             5.0
# 27116  got husband christmas hes computerelectronics ...             5.0
#
#       sentiment
# 14906  positive
# 32141  positive
# 1445   positive
# 31787  positive
# 27116  positive
#
# Sample rows from the dataset_recode for validation:
#                                             reviews.text  reviews.rating  \
# 32888  enjoying amazon firestick tv best investment i...             5.0
# 85     looking tablet highly portable could run direc...             5.0
# 13623                     best choice leave home friends             5.0
# ...

# %%
# Save the new datasets to a CSV file
output_file_v01 = "comb_dataset_drop_approach_v01.csv"
comb_dataset_drop.to_csv(output_file_v01, index=False)
print(f"\nNew dataset saved as '{output_file_v01}'")

output_file_v02 = "comb_dataset_recode_approach_v02.csv"
comb_dataset_recode.to_csv(output_file_v02, index=False)
print(f"\nNew dataset saved as '{output_file_v02}'")
# Out:
# New dataset saved as 'comb_dataset_drop_approach_v01.csv'
#
# New dataset saved as 'comb_dataset_recode_approach_v02.csv'

# %% [markdown]
# # **Splitting the Datasets into train, validation, and test sets.**

# %%
from sklearn.model_selection import train_test_split

# Function to split the dataset into train, validation, and test sets
def split_dataset(dataset, stratify_col='sentiment'):
    # Split into train (70%) and temp (30%) for validation and test
    train, temp = train_test_split(dataset, test_size=0.3, random_state=42, stratify=dataset[stratify_col])
    # Further split temp into validation (15%) and test (15%)
    validation, test = train_test_split(temp, test_size=0.5, random_state=42, stratify=temp[stratify_col])
    return train, validation, test

# Split the `comb_dataset_drop`
print("Splitting `comb_dataset_drop` into train, validation, and test sets...")
train_drop, val_drop, test_drop = split_dataset(comb_dataset_drop)

# Split the `comb_dataset_recode`
print("Splitting `comb_dataset_recode` into train, validation, and test sets...")
train_recode, val_recode, test_recode = split_dataset(comb_dataset_recode)
# Out:
# Splitting `comb_dataset_drop` into train, validation, and test sets...
# Splitting `comb_dataset_recode` into train, validation, and test sets...

# %%
# Verify the sizes of the splits
print(f"Train, validation, and test sizes for `comb_dataset_drop`: {train_drop.shape}, {val_drop.shape}, {test_drop.shape}")
print(f"Train, validation, and test sizes for `comb_dataset_recode`: {train_recode.shape}, {val_recode.shape}, {test_recode.shape}")
# Out:
# Train, validation, and test sizes for `comb_dataset_drop`: (26402, 3), (5658, 3), (5658, 3)
# Train, validation, and test sizes for `comb_dataset_recode`: (25216, 4), (5404, 4), (5404, 4)

# %%
# Save the splits for future use
train_drop.to_csv("comb_train_drop.csv", index=False)
val_drop.to_csv("comb_val_drop.csv", index=False)
test_drop.to_csv("comb_test_drop.csv", index=False)

train_recode.to_csv("comb_train_recode.csv", index=False)
val_recode.to_csv("comb_val_recode.csv", index=False)
test_recode.to_csv("comb_test_recode.csv", index=False)

print("\nDataset splits saved successfully!")
# Out:
# Dataset splits saved successfully!

# %% [markdown]
# # **Data Balancing**

# %%
# Check the class distribution
print("\nClass distribution for train_drop before balancing:")
class_counts_v01 = train_drop['sentiment'].value_counts()
print(class_counts_v01)

# Visualize the class distribution
plt.figure(figsize=(8, 5))
sns.countplot(x='sentiment', data=train_drop, palette='pastel', order=["negative", "neutral", "positive"])
plt.title("Class Distribution for train_drop Before Balancing")
plt.xlabel("Sentiment")
plt.ylabel("Frequency")
plt.show()

# Check the class distribution
print("\nClass distribution for train_drop before balancing:")
class_counts_v02 = train_recode['sentiment'].value_counts()
print(class_counts_v02)

# Visualize the class distribution
plt.figure(figsize=(8, 5))
sns.countplot(x='sentiment', data=train_recode, palette='pastel', order=["negative", "neutral", "positive"])
plt.title("Class Distribution for train_recode Before Balancing")
plt.xlabel("Sentiment")
plt.ylabel("Frequency")
plt.show()
# Out:
# Class distribution for train_drop before balancing:
# sentiment
# positive    22620
# neutral      2029
# negative     1753
# Name: count, dtype: int64
# C:\Users\larry\AppData\Local\Temp\ipykernel_22220\973606603.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sentiment', data=train_drop, palette='pastel', order=["negative", "neutral", "positive"])
# Class distribution for train_drop before balancing:
# sentiment
# positive    22300
# neutral      2028
# negative      888
# Name: count, dtype: int64
# C:\Users\larry\AppData\Local\Temp\ipykernel_22220\973606603.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
"""from sklearn.utils import resample

# Function to balance the training dataset
def balance_training_data(train_set, target_col='sentiment'):
    # Separate classes
    negative = train_set[train_set[target_col] == 'negative']
    neutral = train_set[train_set[target_col] == 'neutral']
    positive = train_set[train_set[target_col] == 'positive']
    
    # Determine the maximum class size
    max_size = max(len(negative), len(neutral), len(positive))
    
    # Oversample minority classes
    negative_balanced = resample(negative, replace=True, n_samples=max_size, random_state=42)
    neutral_balanced = resample(neutral, replace=True, n_samples=max_size, random_state=42)
    positive_balanced = resample(positive, replace=True, n_samples=max_size, random_state=42)
    
    # Combine balanced classes
    balanced_data = pd.concat([negative_balanced, neutral_balanced, positive_balanced])
    # Shuffle the dataset
    balanced_data = balanced_data.sample(frac=1, random_state=42).reset_index(drop=True)
    return balanced_data

# Balance the `train_drop` dataset
print("Balancing `train_drop`...")
balanced_train_drop = balance_training_data(train_drop)

# Balance the `train_recode` dataset
print("Balancing `train_recode`...")
balanced_train_recode = balance_training_data(train_recode)

# Save balanced training sets for future use
balanced_train_drop.to_csv("balanced_train_drop.csv", index=False)
balanced_train_recode.to_csv("balanced_train_recode.csv", index=False)

# Verify class distribution after balancing
print("\nClass distribution after balancing:")
print(balanced_train_drop['sentiment'].value_counts())
print(balanced_train_recode['sentiment'].value_counts())"""
# Out:
# Balancing `train_drop`...
# Balancing `train_recode`...
#
# Class distribution after balancing:
# sentiment
# neutral     22620
# positive    22620
# negative    22620
# Name: count, dtype: int64
# sentiment
# negative    22300
# positive    22300
# neutral     22300
# Name: count, dtype: int64

# %%
"""# Visualize the balanced class distribution
plt.figure(figsize=(8, 5))
sns.countplot(x='sentiment', data=balanced_data_feat, palette='pastel', order=["negative", "neutral", "positive"])
plt.title("Class Distribution After Balancing")
plt.xlabel("Sentiment")
plt.ylabel("Frequency")
plt.show()"""

# %% [markdown]
# # **Tokenization and Lemmatization**

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# Download necessary NLTK resources
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\larry\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\larry\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\larry\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# Initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# Define tokenization and lemmatization function
def preprocess_text(text):
    tokens = word_tokenize(text.lower())  # Tokenize and convert to lowercase
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens if token.isalnum()]  # Lemmatize and remove non-alphanumeric
    return " ".join(lemmatized_tokens)

# Apply preprocessing to all splits and save results
def preprocess_dataset(dataset, text_column='reviews.text'):
    dataset[text_column] = dataset[text_column].apply(preprocess_text)
    return dataset

print("Tokenizing and lemmatizing `train_drop`...")
train_drop = preprocess_dataset(train_drop)
val_drop = preprocess_dataset(val_drop)
test_drop = preprocess_dataset(test_drop)

print("Tokenizing and lemmatizing `train_recode`...")
train_recode = preprocess_dataset(train_recode)
val_recode = preprocess_dataset(val_recode)
test_recode = preprocess_dataset(test_recode)

# Save preprocessed datasets for future use
train_drop.to_csv("preprocessed_comb_train_drop.csv", index=False)
val_drop.to_csv("preprocessed_comb_val_drop.csv", index=False)
test_drop.to_csv("preprocessed_comb_test_drop.csv", index=False)

train_recode.to_csv("preprocessed_comb_train_recode.csv", index=False)
val_recode.to_csv("preprocessed_comb_val_recode.csv", index=False)
test_recode.to_csv("preprocessed_comb_test_recode.csv", index=False)

print("\nPreprocessed datasets saved successfully!")
# Out:
# Tokenizing and lemmatizing `train_drop`...
# Tokenizing and lemmatizing `train_recode`...
#
# Preprocessed datasets saved successfully!

# %% [markdown]
# # **Vectorization applying TF-IDF**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Define the TF-IDF Vectorizer
tfidf_vectorizer = TfidfVectorizer(max_features=10000, ngram_range=(1, 2), stop_words='english')

# Function to vectorize datasets
def vectorize_datasets(train, val, test, text_column='reviews.text'):
    # Fit TF-IDF on the training set
    X_train = tfidf_vectorizer.fit_transform(train[text_column])
    X_val = tfidf_vectorizer.transform(val[text_column])
    X_test = tfidf_vectorizer.transform(test[text_column])
    
    return X_train, X_val, X_test

print("Vectorizing `dataset_drop`...")
X_train_drop, X_val_drop, X_test_drop = vectorize_datasets(train_drop, val_drop, test_drop)

print("Vectorizing `dataset_recode`...")
X_train_recode, X_val_recode, X_test_recode = vectorize_datasets(train_recode, val_recode, test_recode)
# Out:
# Vectorizing `dataset_drop`...
# Vectorizing `dataset_recode`...

# %%
# Save the vectorized features for future use (optional step)
import joblib
joblib.dump(tfidf_vectorizer, "comb_tfidf_vectorizer.pkl")
joblib.dump(X_train_drop, "X_comb_train_drop.pkl")
joblib.dump(X_val_drop, "X_comb_val_drop.pkl")
joblib.dump(X_test_drop, "X_comb_test_drop.pkl")

joblib.dump(X_train_recode, "X_comb_train_recode.pkl")
joblib.dump(X_val_recode, "X_comb_val_recode.pkl")
joblib.dump(X_test_recode, "X_comb_test_recode.pkl")

print("\nVectorized datasets saved successfully!")
# Out:
# Vectorized datasets saved successfully!

# %% [markdown]
# # **Models Training and Evaluation**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
from sklearn.preprocessing import LabelEncoder
import numpy as np

# %%
# Encode sentiment labels into numeric format
encoder = LabelEncoder()
y_train_drop = encoder.fit_transform(train_drop['sentiment'])
y_val_drop = encoder.transform(val_drop['sentiment'])
y_test_drop = encoder.transform(test_drop['sentiment'])

y_train_recode = encoder.fit_transform(train_recode['sentiment'])
y_val_recode = encoder.transform(val_recode['sentiment'])
y_test_recode = encoder.transform(test_recode['sentiment'])

# %%
# Compute class weights for each dataset
class_weights_drop = compute_class_weight(
    class_weight='balanced',  # Automatically calculate weights
    classes=np.unique(y_train_drop),  # Unique classes
    y=y_train_drop  # Target labels
)
class_weights_dict_drop = dict(enumerate(class_weights_drop))

# Print class weights for `dataset_drop`
print("\nClass Weights for `dataset_drop` (encoded labels):")
for label, weight in class_weights_dict_drop.items():
    print(f"Class {encoder.inverse_transform([label])[0]}: Weight = {weight:.4f}")

class_weights_recode = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train_recode),
    y=y_train_recode
)
class_weights_dict_recode = dict(enumerate(class_weights_recode))

# Print class weights for `dataset_recode`
print("\nClass Weights for `dataset_recode` (encoded labels):")
for label, weight in class_weights_dict_recode.items():
    print(f"Class {encoder.inverse_transform([label])[0]}: Weight = {weight:.4f}")
# Out:
# Class Weights for `dataset_drop` (encoded labels):
# Class negative: Weight = 5.0203
# Class neutral: Weight = 4.3374
# Class positive: Weight = 0.3891
#
# Class Weights for `dataset_recode` (encoded labels):
# Class negative: Weight = 9.4655
# Class neutral: Weight = 4.1446
# Class positive: Weight = 0.3769

# %%
print(class_weights_dict_drop[0])
# Out:
# 5.0203460733979846

# %%
# Function to train and evaluate models
def train_evaluate_model(model, X_train, y_train, X_val, y_val, X_test, y_test, model_name):
    print(f"\n--- Training and Evaluating {model_name} ---")
    
    # Train the model
    model.fit(X_train, y_train)
    
    # Validation predictions
    val_predictions = model.predict(X_val)
    val_accuracy = accuracy_score(y_val, val_predictions)
    val_precision = precision_score(y_val, val_predictions, average='macro')
    val_recall = recall_score(y_val, val_predictions, average='macro')
    val_f1 = f1_score(y_val, val_predictions, average='macro')
    
    # Test predictions
    test_predictions = model.predict(X_test)
    test_accuracy = accuracy_score(y_test, test_predictions)
    test_precision = precision_score(y_test, test_predictions, average='macro')
    test_recall = recall_score(y_test, test_predictions, average='macro')
    test_f1 = f1_score(y_test, test_predictions, average='macro')
    
    # Print evaluation metrics
    print(f"\nValidation Metrics ({model_name}):")
    print(f"  Accuracy: {val_accuracy:.4f}")
    print(f"  Precision: {val_precision:.4f}")
    print(f"  Recall: {val_recall:.4f}")
    print(f"  F1-Score: {val_f1:.4f}")
    
    print(f"\nTest Metrics ({model_name}):")
    print(f"  Accuracy: {test_accuracy:.4f}")
    print(f"  Precision: {test_precision:.4f}")
    print(f"  Recall: {test_recall:.4f}")
    print(f"  F1-Score: {test_f1:.4f}")
    
    # Classification report and confusion matrix
    print(f"\nClassification Report ({model_name} - Test Set):\n")
    print(classification_report(y_test, test_predictions, target_names=encoder.classes_))
    
    print(f"\nConfusion Matrix ({model_name} - Test Set):\n")
    print(confusion_matrix(y_test, test_predictions))

# Prepare models
logistic_model_drop = LogisticRegression(class_weight=class_weights_dict_drop, max_iter=1000)
svm_model_drop = SVC(class_weight='balanced', probability=True)  # SVM uses balanced weights automatically
random_forest_model_drop = RandomForestClassifier(class_weight=class_weights_dict_drop, random_state=42)
xgboost_model_drop = XGBClassifier(scale_pos_weight=class_weights_dict_drop[0], eval_metric='logloss', random_state=42)

# Train and evaluate on `dataset_drop`
print("\nEvaluating on `dataset_drop`...")
train_evaluate_model(logistic_model_drop, X_train_drop, y_train_drop, X_val_drop, y_val_drop, X_test_drop, y_test_drop, "Logistic Regression")
train_evaluate_model(svm_model_drop, X_train_drop, y_train_drop, X_val_drop, y_val_drop, X_test_drop, y_test_drop, "SVM")
train_evaluate_model(random_forest_model_drop, X_train_drop, y_train_drop, X_val_drop, y_val_drop, X_test_drop, y_test_drop, "Random Forest")
train_evaluate_model(xgboost_model_drop, X_train_drop, y_train_drop, X_val_drop, y_val_drop, X_test_drop, y_test_drop, "XGBoost")

# Repeat the same for `dataset_recode`
logistic_model_recode = LogisticRegression(class_weight=class_weights_dict_recode, max_iter=1000)
svm_model_recode = SVC(class_weight='balanced', probability=True)
random_forest_model_recode = RandomForestClassifier(class_weight=class_weights_dict_recode, random_state=42)
xgboost_model_recode = XGBClassifier(scale_pos_weight=class_weights_dict_recode[0], eval_metric='logloss', random_state=42)

print("\nEvaluating on `dataset_recode`...")
train_evaluate_model(logistic_model_recode, X_train_recode, y_train_recode, X_val_recode, y_val_recode, X_test_recode, y_test_recode, "Logistic Regression")
train_evaluate_model(svm_model_recode, X_train_recode, y_train_recode, X_val_recode, y_val_recode, X_test_recode, y_test_recode, "SVM")
train_evaluate_model(random_forest_model_recode, X_train_recode, y_train_recode, X_val_recode, y_val_recode, X_test_recode, y_test_recode, "Random Forest")
train_evaluate_model(xgboost_model_recode, X_train_recode, y_train_recode, X_val_recode, y_val_recode, X_test_recode, y_test_recode, "XGBoost")
# Out:
# Evaluating on `dataset_drop`...
#
# --- Training and Evaluating Logistic Regression ---
#
# Validation Metrics (Logistic Regression):
#   Accuracy: 0.8591
#   Precision: 0.6465
#   Recall: 0.7805
#   F1-Score: 0.6941
#
# Test Metrics (Logistic Regression):
#   Accuracy: 0.8685
#   Precision: 0.6578
#   Recall: 0.7769
#   F1-Score: 0.7019
#
# Classification Report (Logistic Regression - Test Set):
#
#               precision    recall  f1-score   support
#
#     negative       0.61      0.78      0.68       376
#      neutral       0.39      0.66      0.49       435
#     positive       0.98      0.89      0.93      4847
#
#     accuracy                           0.87      5658
#    macro avg       0.66      0.78      0.70      5658
# weighted avg       0.91      0.87      0.88      5658
#
#
# Confusion Matrix (Logistic Regression - Test Set):
#
# [[ 292   56   28]
#  [  67  287   81]
#  [ 123  389 4335]]
#
# --- Training and Evaluating SVM ---
#
# Validation Metrics (SVM):
# ...

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, confusion_matrix, f1_score

# Function to perform GridSearchCV for SVM

def grid_search_svm(X_train, y_train, X_val, y_val, dataset_name):
    print(f"\n--- Starting Grid Search for SVM on {dataset_name} ---")

    param_grid_svm = {
        'C': [0.1, 1, 10],
        'kernel': ['linear', 'rbf'],
        'gamma': ['scale', 'auto']
    }

    svm_model = SVC(class_weight='balanced', probability=True)

    grid_search = GridSearchCV(
        estimator=svm_model,
        param_grid=param_grid_svm,
        scoring='f1_macro',
        cv=5,
        verbose=1
    )

    grid_search.fit(X_train, y_train)

    best_params = grid_search.best_params_
    print(f"Best Parameters for SVM ({dataset_name}):", best_params)
    best_model = grid_search.best_estimator_

    # Evaluate on validation set
    val_predictions = best_model.predict(X_val)
    val_f1_score = f1_score(y_val, val_predictions, average='macro')
    print(f"Validation F1 Macro Score (SVM - {dataset_name}):", val_f1_score)

    return best_model, best_params

# Perform Grid Search for SVM on dataset_drop
print("\nEvaluating `dataset_drop`...")
svm_best_model_drop, svm_best_params_drop = grid_search_svm(X_train_drop, y_train_drop, X_val_drop, y_val_drop, "dataset_drop")

# Perform Grid Search for SVM and XGBoost on dataset_recode
print("\nEvaluating `dataset_recode`...")
svm_best_model_recode, svm_best_params_recode = grid_search_svm(X_train_recode, y_train_recode, X_val_recode, y_val_recode, "dataset_recode")
# Out:
# Evaluating `dataset_drop`...
#
# --- Starting Grid Search for SVM on dataset_drop ---
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Best Parameters for SVM (dataset_drop): {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Validation F1 Macro Score (SVM - dataset_drop): 0.7794762589928373
#
# Evaluating `dataset_recode`...
#
# --- Starting Grid Search for SVM on dataset_recode ---
# Fitting 5 folds for each of 12 candidates, totalling 60 fits

# %% [markdown]
# # **XGBoost Classifier using tunned hyperparammeters and Sample Weights**

# %%
# Updated XGBoost models with sample weights for all classes
def train_evaluate_xgboost_with_weights(X_train, y_train, X_val, y_val, X_test, y_test, sample_weights, model_name, encoder):
    print(f"\n--- Training and Evaluating {model_name} ---")
    
    xgb_model = XGBClassifier(
        colsample_bytree=0.8,
        learning_rate=0.2,
        max_depth=7,
        n_estimators=200,
        subsample=0.8,
        eval_metric='logloss',
        use_label_encoder=False,
        random_state=42
    )
    
    # Train the model with sample weights
    xgb_model.fit(X_train, y_train, sample_weight=sample_weights)
    
    # Validation predictions
    val_predictions = xgb_model.predict(X_val)
    val_accuracy = accuracy_score(y_val, val_predictions)
    val_precision = precision_score(y_val, val_predictions, average='macro')
    val_recall = recall_score(y_val, val_predictions, average='macro')
    val_f1 = f1_score(y_val, val_predictions, average='macro')
    
    # Test predictions
    test_predictions = xgb_model.predict(X_test)
    test_accuracy = accuracy_score(y_test, test_predictions)
    test_precision = precision_score(y_test, test_predictions, average='macro')
    test_recall = recall_score(y_test, test_predictions, average='macro')
    test_f1 = f1_score(y_test, test_predictions, average='macro')
    
    # Print evaluation metrics
    print(f"\nValidation Metrics ({model_name}):")
    print(f"  Accuracy: {val_accuracy:.4f}")
    print(f"  Precision: {val_precision:.4f}")
    print(f"  Recall: {val_recall:.4f}")
    print(f"  F1-Score: {val_f1:.4f}")
    
    print(f"\nTest Metrics ({model_name}):")
    print(f"  Accuracy: {test_accuracy:.4f}")
    print(f"  Precision: {test_precision:.4f}")
    print(f"  Recall: {test_recall:.4f}")
    print(f"  F1-Score: {test_f1:.4f}")
    
    # Classification report and confusion matrix
    print(f"\nClassification Report ({model_name} - Test Set):\n")
    print(classification_report(y_test, test_predictions, target_names=encoder.classes_))
    
    print(f"\nConfusion Matrix ({model_name} - Test Set):\n")
    conf_matrix = confusion_matrix(y_test, test_predictions)
    print(conf_matrix)
    
    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_)
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title(f"Confusion Matrix ({model_name})")
    plt.show()

# Prepare sample weights for datasets
sample_weights_drop = np.array([5.0203 if label == 0 else 4.3374 if label == 1 else 0.3891 for label in y_train_drop])
sample_weights_recode = np.array([9.4655 if label == 0 else 4.1446 if label == 1 else 0.3769 for label in y_train_recode])

# Train and evaluate on `dataset_drop`
print("\nEvaluating XGBoost on `dataset_drop` with sample weights...")
train_evaluate_xgboost_with_weights(
    X_train_drop, y_train_drop, X_val_drop, y_val_drop, X_test_drop, y_test_drop, 
    sample_weights_drop, "XGBoost (dataset_drop)", encoder
)

# Train and evaluate on `dataset_recode`
print("\nEvaluating XGBoost on `dataset_recode` with sample weights...")
train_evaluate_xgboost_with_weights(
    X_train_recode, y_train_recode, X_val_recode, y_val_recode, X_test_recode, y_test_recode, 
    sample_weights_recode, "XGBoost (dataset_recode)", encoder
)
# Out:
# Evaluating XGBoost on `dataset_drop` with sample weights...
#
# --- Training and Evaluating XGBoost (dataset_drop) ---
# c:\Users\larry\anaconda3\envs\projectnlp\Lib\site-packages\xgboost\core.py:158: UserWarning: [08:48:44] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Validation Metrics (XGBoost (dataset_drop)):
#   Accuracy: 0.8630
#   Precision: 0.6434
#   Recall: 0.7656
#   F1-Score: 0.6892
#
# Test Metrics (XGBoost (dataset_drop)):
#   Accuracy: 0.8667
#   Precision: 0.6482
#   Recall: 0.7639
#   F1-Score: 0.6924
#
# Classification Report (XGBoost (dataset_drop) - Test Set):
#
#               precision    recall  f1-score   support
#
#     negative       0.58      0.78      0.67       376
#      neutral       0.39      0.61      0.48       435
# ...

# %% [markdown]
# # **RandomForrest Classifier using tunned hyperparammeters and Class Weights**

# %%
from sklearn.svm import SVC
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, f1_score, precision_score, recall_score, accuracy_score
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Function to compute class weights and encode labels
def compute_class_weights_and_encode(y_train, encoder):
    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(y_train),
        y=y_train
    )
    class_weights_dict = {label: weight for label, weight in zip(np.unique(y_train), class_weights)}
    return class_weights_dict

# Function to train and evaluate models
def train_evaluate_model(model, X_train, y_train, X_val, y_val, X_test, y_test, model_name):
    print(f"\n--- Training and Evaluating {model_name} ---")

    # Train the model
    model.fit(X_train, y_train)

    # Validation predictions
    val_predictions = model.predict(X_val)
    val_accuracy = accuracy_score(y_val, val_predictions)
    val_precision = precision_score(y_val, val_predictions, average='macro')
    val_recall = recall_score(y_val, val_predictions, average='macro')
    val_f1 = f1_score(y_val, val_predictions, average='macro')

    # Test predictions
    test_predictions = model.predict(X_test)
    test_accuracy = accuracy_score(y_test, test_predictions)
    test_precision = precision_score(y_test, test_predictions, average='macro')
    test_recall = recall_score(y_test, test_predictions, average='macro')
    test_f1 = f1_score(y_test, test_predictions, average='macro')

    # Print evaluation metrics
    print(f"\nValidation Metrics ({model_name}):")
    print(f"  Accuracy: {val_accuracy:.4f}")
    print(f"  Precision: {val_precision:.4f}")
    print(f"  Recall: {val_recall:.4f}")
    print(f"  F1-Score: {val_f1:.4f}")

    print(f"\nTest Metrics ({model_name}):")
    print(f"  Accuracy: {test_accuracy:.4f}")
    print(f"  Precision: {test_precision:.4f}")
    print(f"  Recall: {test_recall:.4f}")
    print(f"  F1-Score: {test_f1:.4f}")

    # Classification report and confusion matrix
    print(f"\nClassification Report ({model_name} - Test Set):\n")
    print(classification_report(y_test, test_predictions, target_names=encoder.classes_))

    print(f"\nConfusion Matrix ({model_name} - Test Set):\n")
    conf_matrix = confusion_matrix(y_test, test_predictions)
    print(conf_matrix)

    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_)
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title(f"Confusion Matrix ({model_name})")
    plt.show()

# Prepare models
rf_model_drop = RandomForestClassifier(
    n_estimators=300,
    max_depth=None,
    min_samples_split=5,
    min_samples_leaf=1,
    bootstrap=False,
    class_weight=class_weights_dict_drop,
    random_state=42
)

rf_model_recode = RandomForestClassifier(
    n_estimators=300,
    max_depth=None,
    min_samples_split=5,
    min_samples_leaf=1,
    bootstrap=False,
    class_weight=class_weights_dict_recode,
    random_state=42
)

# Train and evaluate Random Forest on dataset_drop
print("\nEvaluating on `dataset_drop`...")
train_evaluate_model(rf_model_drop, X_train_drop, y_train_drop, X_val_drop, y_val_drop, X_test_drop, y_test_drop, "Random Forest (dataset_drop)")

# Train and evaluate Random Forest on dataset_recode
print("\nEvaluating on `dataset_recode`...")
train_evaluate_model(rf_model_recode, X_train_recode, y_train_recode, X_val_recode, y_val_recode, X_test_recode, y_test_recode, "Random Forest (dataset_recode)")

# %%
'''# Function to compute sample weights
def compute_sample_weights(y_train, class_weights_dict):
    return np.array([class_weights_dict[label] for label in y_train])

# Compute sample weights for each dataset
sample_weights_drop = compute_sample_weights(y_train_drop, class_weights_dict_drop)
sample_weights_recode = compute_sample_weights(y_train_recode, class_weights_dict_recode)'''

# Updated XGBoost Models without `scale_pos_weight`
xgb_model_drop = XGBClassifier(
    colsample_bytree=0.8,
    learning_rate=0.2,
    max_depth=5,
    n_estimators=200,
    subsample=0.8,
    eval_metric='logloss',
    use_label_encoder=False,
    random_state=42
)

xgb_model_recode = XGBClassifier(
    colsample_bytree=0.8,
    learning_rate=0.2,
    max_depth=7,
    n_estimators=200,
    subsample=0.8,
    eval_metric='logloss',
    use_label_encoder=False,
    random_state=42
)

# Train and evaluate XGBoost on `dataset_drop` with sample weights
print("\nEvaluating on `dataset_drop`...")
xgb_model_drop.fit(X_train_drop, y_train_drop, sample_weight=sample_weights_drop)
train_evaluate_model(xgb_model_drop, X_train_drop, y_train_drop, X_val_drop, y_val_drop, X_test_drop, y_test_drop, "XGBoost (dataset_drop)")

# Train and evaluate XGBoost on `dataset_recode` with sample weights
print("\nEvaluating on `dataset_recode`...")
xgb_model_recode.fit(X_train_recode, y_train_recode, sample_weight=sample_weights_recode)
train_evaluate_model(xgb_model_recode, X_train_recode, y_train_recode, X_val_recode, y_val_recode, X_test_recode, y_test_recode, "XGBoost (dataset_recode)")

# %%
# Function to perform GridSearchCV for XGBoost

def grid_search_xgboost(X_train, y_train, X_val, y_val, dataset_name):
    print(f"\n--- Starting Grid Search for XGBoost on {dataset_name} ---")

    param_grid_xgb = {
        'max_depth': [3, 5, 7],
        'learning_rate': [0.01, 0.1, 0.2],
        'n_estimators': [100, 200, 300],
        'subsample': [0.8, 1.0],
        'colsample_bytree': [0.8, 1.0]
    }

    xgb_model = XGBClassifier(
        eval_metric='logloss',
        use_label_encoder=False,
        random_state=42
    )

    grid_search = GridSearchCV(
        estimator=xgb_model,
        param_grid=param_grid_xgb,
        scoring='f1_macro',
        cv=5,
        verbose=1
    )

    grid_search.fit(X_train, y_train)

    best_params = grid_search.best_params_
    print(f"Best Parameters for XGBoost ({dataset_name}):", best_params)
    best_model = grid_search.best_estimator_

    # Evaluate on validation set
    val_predictions = best_model.predict(X_val)
    val_f1_score = f1_score(y_val, val_predictions, average='macro')
    print(f"Validation F1 Macro Score (XGBoost - {dataset_name}):", val_f1_score)

    return best_model, best_params

# Perform Grid Search for SVM and XGBoost on dataset_drop
print("\nEvaluating `dataset_drop`...")
svm_best_model_drop, svm_best_params_drop = grid_search_svm(X_train_drop, y_train_drop, X_val_drop, y_val_drop, "dataset_drop")
xgb_best_model_drop, xgb_best_params_drop = grid_search_xgboost(X_train_drop, y_train_drop, X_val_drop, y_val_drop, "dataset_drop")

# Perform Grid Search for SVM and XGBoost on dataset_recode
print("\nEvaluating `dataset_recode`...")
svm_best_model_recode, svm_best_params_recode = grid_search_svm(X_train_recode, y_train_recode, X_val_recode, y_val_recode, "dataset_recode")
xgb_best_model_recode, xgb_best_params_recode = grid_search_xgboost(X_train_recode, y_train_recode, X_val_recode, y_val_recode, "dataset_recode")
